# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO, BytesIO
from urllib.parse import urlparse, urljoin

# Function to fetch repository content using web scraping
def fetch_repo_content(repo_url):
    repo_url = repo_url.rstrip('/')
    print(f"Fetching content from: {repo_url}")  # Debug statement
    
    try:
        response = requests.get(repo_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        return parse_repo_content(soup, repo_url), "Public"
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch content: {e}")  # Debug statement
        return None, "Private"

# Function to parse the HTML content of the repository page
def parse_repo_content(soup, base_url):
    content_list = []
    items = soup.find_all('a', class_='Link--primary')  # Adjusted to target the correct class for navigation

    for item in items:
        name = item.text.strip()
        if not name or name == "..":  # Skip empty names and parent directory link
            continue
        print(f"Found item: {name}")  # Debug statement
        href = item['href']
        if href.endswith('.csv') or href.endswith('.xlsx'):
            file_url = urljoin(base_url, href.replace('/blob/', '/raw/'))
            content_list.append((file_url, 'Yes'))  # Root directory indicator
            print(f"Found data file in root: {name}, URL: {file_url}")  # Debug statement
        elif 'tree' in href:
            subdir_url = urljoin(base_url, href)
            print(f"Fetching subdirectory content from: {subdir_url}")  # Debug statement
            sub_content, _ = fetch_repo_content(subdir_url)
            if sub_content:
                content_list.extend([(file_url, 'No') for file_url, _ in sub_content])  # Subdirectory indicator
    return content_list

# Function to validate CSV/XLSX against submission criteria
def validate_data_file(file_url, sample_df):
    print(f"Validating file: {file_url}")  # Debug statement
    response = requests.get(file_url)
    if response.status_code == 200:
        if file_url.endswith('.csv'):
            data_df = pd.read_csv(StringIO(response.text))
        elif file_url.endswith('.xlsx'):
            data_df = pd.read_excel(BytesIO(response.content))

        # Ensure columns match with flexible naming conventions
        if ('respondent_id' in data_df.columns and
            (('xyz_vaccine' in data_df.columns and 'seasonal_vaccine' in data_df.columns) or
             ('h1n1_vaccine' in data_df.columns and 'seasonal_vaccine' in data_df.columns))):

            print("Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']")  # Debug statement

            # No need to enforce sorting or serial order of respondent_id

            # Check if respondent_id values are consistent
            if 'respondent_id' in data_df.columns:
                print("Validating respondent_id consistency...")  # Debug statement
                return True
            else:
                print("Missing required columns (respondent_id, xyz_vaccine/h1n1_vaccine, seasonal_vaccine).")  # Debug statement
        else:
            print(f"Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: {data_df.columns.tolist()}")  # Debug statement
    else:
        print(f"Failed to fetch file from {file_url}. Status code: {response.status_code}")  # Debug statement

    return False

# Main function to process each repository and find valid submission files
def process_repositories(repo_urls, sample_df):
    results = []
    for repo_url in repo_urls:
        if "github.com" not in repo_url:
            results.append((repo_url, "Invalid URL", "Unknown", "N/A", "N/A"))  # Adjusted to include a placeholder for most recent valid submission URL
            print(f"Skipping invalid URL: {repo_url}")  # Debug statement
            continue

        content_list, repo_status = fetch_repo_content(repo_url)
        if not content_list:
            results.append((repo_url, "No content found", repo_status, "N/A", "N/A"))  # Adjusted to include placeholders for most recent valid submission URL
            print(f"No content found in repository: {repo_url}")  # Debug statement
            continue

        valid_submissions = []
        for file_url, is_root_dir in content_list:
            if validate_data_file(file_url, sample_df):
                valid_submissions.append((file_url, is_root_dir))

        if valid_submissions:
            most_recent_submission = valid_submissions[-1]  # Get the most recent valid submission
            results.append((repo_url, "Valid submission found", repo_status, most_recent_submission[1], most_recent_submission[0]))  # Include most recent valid submission URL
            print(f"Valid submission found in repository: {repo_url}")  # Debug statement
        else:
            results.append((repo_url, "No valid submission found", repo_status, "N/A", "N/A"))  # Adjusted to include placeholders for most recent valid submission URL
            print(f"No valid submission found in repository: {repo_url}")  # Debug statement

    return results

# Read Excel file containing GitHub repository links
repo_urls_df = pd.read_excel('links_of_submission.xlsx', header=None)
repo_urls = repo_urls_df.iloc[:, 0].tolist()  # Read the first (and only) column
print(f"Reading {len(repo_urls)} repository URLs from 'links_of_submission.xlsx'...")  # Debug statement

# Read sample CSV file to determine submission criteria
sample_df = pd.read_csv('submission_format.csv')
print("Sample submission criteria loaded successfully.")  # Debug statement

# Process repositories and get results
print("Processing repositories...")  # Debug statement
results = process_repositories(repo_urls, sample_df)

# Create a DataFrame to summarize the results
results_df = pd.DataFrame(results, columns=['Repository URL', 'Submission Status', 'Repository Visibility', 'Submission in Root Dir', 'Most Recent Valid Submission URL'])
print("Results processed.")  # Debug statement

# Save the results to a CSV file
results_df.to_csv('submission_results.csv', index=False)
print("Results saved to 'submission_results.csv'. Processing complete.")  # Debug statement
# Out:
# Reading 199 repository URLs from 'links_of_submission.xlsx'...
# Sample submission criteria loaded successfully.
# Processing repositories...
# Fetching content from: https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati
# Found item: Hackathon.ipynb
# Found item: Hackathon.ipynb
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati/raw/main/submission.csv
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati/raw/main/submission.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon
# Found item: Solution
# Fetching subdirectory content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/%20Solution
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/%20Solution
# Found item: script.py
# Found item: script.py
# Found item: Solution
# Fetching subdirectory content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/%20Solution
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/%20Solution
# Found item: script.py
# Found item: script.py
# Found item: Datasets
# Fetching subdirectory content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Datasets
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Datasets
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Found item: Datasets
# Fetching subdirectory content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Datasets
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Datasets
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Found item: Output
# Fetching subdirectory content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Output
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Output
# Found item: Output
# Fetching subdirectory content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Output
# Fetching content from: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon/Output
# Found item: Problem description.pdf
# Found item: Problem description.pdf
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/gursharankaur13/Summer-Analytics-2024/raw/main/Week%203%20Hackathon/Datasets/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon
# Fetching content from: https://github.com/jigs-bot/GFG_DataHack
# Found item: README.md
# Found item: README.md
# Found item: Week03_Hackathon.ipynb
# Found item: Week03_Hackathon.ipynb
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/jigs-bot/GFG_DataHack/raw/main/submission.csv
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/jigs-bot/GFG_DataHack/raw/main/submission.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/jigs-bot/GFG_DataHack/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/jigs-bot/GFG_DataHack/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/jigs-bot/GFG_DataHack
# Fetching content from: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-
# Found item: geeksFORgeeks.ipynb
# Found item: geeksFORgeeks.ipynb
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/submission.csv
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/submission.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/test_set_features.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/test_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_features.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_labels.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_labels.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/raw/main/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-
# Fetching content from: https://github.com/iam-venkat03/gfg_datahackathon_iitg
# Found item: xg_test_data.xlsx
# Found data file in root: xg_test_data.xlsx, URL: https://github.com/iam-venkat03/gfg_datahackathon_iitg/raw/main/xg_test_data.xlsx
# Found item: xg_test_data.xlsx
# Found data file in root: xg_test_data.xlsx, URL: https://github.com/iam-venkat03/gfg_datahackathon_iitg/raw/main/xg_test_data.xlsx
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/iam-venkat03/gfg_datahackathon_iitg/raw/main/xg_test_data.xlsx
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/iam-venkat03/gfg_datahackathon_iitg/raw/main/xg_test_data.xlsx
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/iam-venkat03/gfg_datahackathon_iitg
# Fetching content from: https://github.com/rishabhluwang/RishabhSingha_Datahack.git
# Found item: code.ipynb
# Found item: code.ipynb
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/rishabhluwang/RishabhSingha_Datahack/raw/main/submission.csv
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/rishabhluwang/RishabhSingha_Datahack/raw/main/submission.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/rishabhluwang/RishabhSingha_Datahack/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/rishabhluwang/RishabhSingha_Datahack/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/rishabhluwang/RishabhSingha_Datahack.git
# Fetching content from: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC
# Found item: dataset and all
# Fetching subdirectory content from: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/tree/main/dataset%20and%20all
# Fetching content from: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/tree/main/dataset%20and%20all
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Found item: dataset and all
# Fetching subdirectory content from: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/tree/main/dataset%20and%20all
# Fetching content from: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/tree/main/dataset%20and%20all
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Found item: submission_format.csv
# Found data file in root: submission_format.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Found item: DataHack By IITG- Utsav Hingar.ipynb
# Found item: DataHack By IITG- Utsav Hingar.ipynb
# Found item: README.md
# Found item: README.md
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/submission.csv
# Found item: submission.csv
# Found data file in root: submission.csv, URL: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/submission.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/dataset%20and%20all/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/raw/main/submission.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC
# Fetching content from: https://github.com/paras28-05/Summer_analytic_program
# Failed to fetch content: 404 Client Error: Not Found for url: https://github.com/paras28-05/Summer_analytic_program
# No content found in repository: https://github.com/paras28-05/Summer_analytic_program
# Fetching content from: https://github.com/subhadipgit07/Vaccine_Data_Hackacthon.git
# Found item: Submission_Hackathon.csv
# Found data file in root: Submission_Hackathon.csv, URL: https://github.com/subhadipgit07/Vaccine_Data_Hackacthon/raw/main/Submission_Hackathon.csv
# Found item: Submission_Hackathon.csv
# Found data file in root: Submission_Hackathon.csv, URL: https://github.com/subhadipgit07/Vaccine_Data_Hackacthon/raw/main/Submission_Hackathon.csv
# Found item: Vaccine_Hackathon_Part-1(Upto_Test_Data Cleaning).ipynb
# Found item: Vaccine_Hackathon_Part-1(Upto_Test_Data Cleaning).ipynb
# Found item: Vaccine_Hackathon_Part-2(Algorithm apply).ipynb
# Found item: Vaccine_Hackathon_Part-2(Algorithm apply).ipynb
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/subhadipgit07/Vaccine_Data_Hackacthon/raw/main/Submission_Hackathon.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/subhadipgit07/Vaccine_Data_Hackacthon/raw/main/Submission_Hackathon.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/subhadipgit07/Vaccine_Data_Hackacthon.git
# Fetching content from: https://github.com/saarthak5/Summer-Analytics-Datahack
# Found item: datasets
# Fetching subdirectory content from: https://github.com/saarthak5/Summer-Analytics-Datahack/tree/main/datasets
# Fetching content from: https://github.com/saarthak5/Summer-Analytics-Datahack/tree/main/datasets
# Found item: datasets
# Fetching subdirectory content from: https://github.com/saarthak5/Summer-Analytics-Datahack/tree/main/datasets
# Fetching content from: https://github.com/saarthak5/Summer-Analytics-Datahack/tree/main/datasets
# Found item: README.md
# Found item: README.md
# Found item: Untitled.ipynb
# Found item: Untitled.ipynb
# Found item: final.csv
# Found data file in root: final.csv, URL: https://github.com/saarthak5/Summer-Analytics-Datahack/raw/main/final.csv
# Found item: final.csv
# Found data file in root: final.csv, URL: https://github.com/saarthak5/Summer-Analytics-Datahack/raw/main/final.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/saarthak5/Summer-Analytics-Datahack/raw/main/final.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/saarthak5/Summer-Analytics-Datahack/raw/main/final.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/saarthak5/Summer-Analytics-Datahack
# Fetching content from: https://github.com/Ankush142930/DataHack_Solution
# Failed to fetch content: 404 Client Error: Not Found for url: https://github.com/Ankush142930/DataHack_Solution
# No content found in repository: https://github.com/Ankush142930/DataHack_Solution
# Fetching content from: https://github.com/Dh1962/GFGHackathon_sa
# Found item: README.md
# Found item: README.md
# Found item: hackathon.ipynb
# Found item: hackathon.ipynb
# Found item: output.csv
# Found data file in root: output.csv, URL: https://github.com/Dh1962/GFGHackathon_sa/raw/main/output.csv
# Found item: output.csv
# Found data file in root: output.csv, URL: https://github.com/Dh1962/GFGHackathon_sa/raw/main/output.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/Dh1962/GFGHackathon_sa/raw/main/output.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/Dh1962/GFGHackathon_sa/raw/main/output.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/Dh1962/GFGHackathon_sa
# Fetching content from: https://github.com/cateto56/Hackathon
# Found item: problem.ipynb
# Found item: problem.ipynb
# Found item: result.csv
# Found data file in root: result.csv, URL: https://github.com/cateto56/Hackathon/raw/main/result.csv
# Found item: result.csv
# Found data file in root: result.csv, URL: https://github.com/cateto56/Hackathon/raw/main/result.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/cateto56/Hackathon/raw/main/result.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/cateto56/Hackathon/raw/main/result.csv
# ...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/submission_format.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/dataset/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/final.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/swatiswapna/swati_swapna_Datahack/raw/main/final.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/swatiswapna/swati_swapna_Datahack.git
# Fetching content from: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack
# Found item: datahack.ipynb
# Found item: datahack.ipynb
# Found item: submission (1).csv
# Found data file in root: submission (1).csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/submission%20(1).csv
# Found item: submission (1).csv
# Found data file in root: submission (1).csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/submission%20(1).csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/test_set_features.csv
# Found item: test_set_features.csv
# Found data file in root: test_set_features.csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/test_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_features.csv
# Found item: training_set_features.csv
# Found data file in root: training_set_features.csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_features.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_labels.csv
# Found item: training_set_labels.csv
# Found data file in root: training_set_labels.csv, URL: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_labels.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/submission%20(1).csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/submission%20(1).csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/test_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_features.csv
# Columns do not match with sample DataFrame. Expected: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine'], Found: ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa', 'household_adults', 'household_children', 'employment_industry', 'employment_occupation']
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack/raw/main/training_set_labels.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack
# Fetching content from: https://github.com/svunofficial/Shivashish_DataHack.git
# Found item: DataHack.ipynb
# Found item: DataHack.ipynb
# Found item: result_datahack.csv
# Found data file in root: result_datahack.csv, URL: https://github.com/svunofficial/Shivashish_DataHack/raw/main/result_datahack.csv
# Found item: result_datahack.csv
# Found data file in root: result_datahack.csv, URL: https://github.com/svunofficial/Shivashish_DataHack/raw/main/result_datahack.csv
# Found item: Releases
# Found item: Packages
#       0
# Validating file: https://github.com/svunofficial/Shivashish_DataHack/raw/main/result_datahack.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Validating file: https://github.com/svunofficial/Shivashish_DataHack/raw/main/result_datahack.csv
# Columns match with sample DataFrame: ['respondent_id', 'xyz_vaccine/h1n1_vaccine', 'seasonal_vaccine']
# Validating respondent_id consistency...
# Valid submission found in repository: https://github.com/svunofficial/Shivashish_DataHack.git
# Results processed.
# Results saved to 'submission_results.csv'. Processing complete.
